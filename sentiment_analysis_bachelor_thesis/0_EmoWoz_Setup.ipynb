# %%
#Files needed for this code to work:
#1. emowoz-multiwoz.json from https://zenodo.org/record/6506504#.ZFF4gc7P3b1
#2. README.md file from https://zenodo.org/record/6506504#.ZFF4gc7P3b1

#Both files are also available in the repo https://github.com/FinnHet13/CodingProjects/tree/main/sentiment_analysis_bachelor_thesis with "README.md" being named "EmoWoz_README.md".

# %% [markdown]
# # Step 1: Import required packages

# %%
import json
import pandas as pd
import numpy as np
import os
import pprint

# %% [markdown]
# # Step 2: Import EmoWoz json file

# %%
with open('emowoz-multiwoz.json', 'r') as f:
    emowoz_database = json.load(f)

#looking at the structure and first few elements of the EmoWoz dataset
pprint.pprint(list(emowoz_database.items())[:5])
# Out:
# [('PMUL2335.json',
#   {'log': [{'dialog_act': {'Restaurant-Inform': [['Food', 'european']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bd033a'},
#                         {'annotation': 0, 'annotator': '13de8dba'},
#                         {'annotation': 0, 'annotator': 'c522c02d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Restaurant-Inform', 'Food', 'european', 8, 8]],
#             'text': 'How are you doing? Are there any European restaurants in '
#                     'the city center?'},
#            {'dialog_act': {'Restaurant-Inform': [['Choice', '8']],
#                            'Restaurant-Request': [['Price', '?']]},
#             'emotion': [],
#             'span_info': [['Restaurant-Inform', 'Choice', '8', 4, 4]],
#             'text': 'Yes, there are 8. What is your price range?'},
#            {'dialog_act': {'Restaurant-Inform': [['Price', 'cheap']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bd033a'},
#                         {'annotation': 0, 'annotator': '13de8dba'},
#                         {'annotation': 0, 'annotator': 'c522c02d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [],
#             'text': 'Can I get the name and address of one of the most '
#                     'inexpensive ones?'},
#            {'dialog_act': {'Restaurant-Recommend': [['Name',
#                                                      'River Bar Steakhouse and '
#                                                      'Grill'],
#                                                     ['Addr',
#                                                      'Quayside Off Bridge '
#                                                      'Street'],
#                                                     ['Phone', '01223307030']]},
#             'emotion': [],
#             'span_info': [['Restaurant-Recommend',
#                            'Name',
#                            'River Bar Steakhouse and Grill',
#                            5,
#                            9],
#                           ['Restaurant-Recommend',
#                            'Addr',
#                            'Quayside Off Bridge Street',
#                            16,
#                            19],
#                           ['Restaurant-Recommend',
#                            'Phone',
#                            '01223307030',
#                            11,
#                            11]],
#             'text': 'The phone number to the River Bar Steakhouse and Grill is '
#                     '01223307030 and the address is Quayside Off Bridge '
#                     'Street. '},
#            {'dialog_act': {'general-thank': [['none', 'none']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bd033a'},
#                         {'annotation': 6, 'annotator': '13de8dba'},
#                         {'annotation': 6, 'annotator': 'c522c02d'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [],
#             'text': 'Thanks so much. I am also looking for places to go in '
#                     'town. Can you help me with that?'},
#            {'dialog_act': {'Attraction-Request': [['Type', '?']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'What type of place are you looking for?'},
#            {'dialog_act': {'Attraction-Inform': [['Type', 'college']],
#                            'Attraction-Request': [['Area', '?']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bd033a'},
#                         {'annotation': 0, 'annotator': '13de8dba'},
#                         {'annotation': 0, 'annotator': 'c522c02d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Attraction-Inform', 'Type', 'college', 5, 5]],
#             'text': 'I would like to see colleges.  Can you please recommend '
#                     'one with no entrance fee, and let me know the area.  '
#                     'Thank you.'},
#            {'dialog_act': {'Attraction-Recommend': [['Area',
#                                                      'west part of town'],
#                                                     ['Fee', 'free'],
#                                                     ['Name',
#                                                      'Churchhill College']]},
#             'emotion': [],
#             'span_info': [['Attraction-Recommend',
#                            'Area',
#                            'west part of town',
#                            7,
#                            10],
#                           ['Attraction-Recommend', 'Fee', 'free', 3, 3],
#                           ['Attraction-Recommend',
#                            'Name',
#                            'Churchhill College',
#                            0,
#                            1]],
#             'text': 'Churchhill College is free and in the west part of town '},
#            {'dialog_act': {'general-thank': [['none', 'none']]},
#             'emotion': [{'annotation': 6, 'annotator': '68bd033a'},
#                         {'annotation': 6, 'annotator': '13de8dba'},
#                         {'annotation': 6, 'annotator': 'c522c02d'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [],
#             'text': 'Thank you.  That was all I needed.'},
#            {'dialog_act': {'general-bye': [['none', 'none']],
#                            'general-greet': [['none', 'none']],
#                            'general-welcome': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'It was a pleasure assisting you. Have a wonderful night. '
#                     'Goodbye. '}]}),
#  ('MUL0425.json',
#   {'log': [{'dialog_act': {'Train-Inform': [['Dest', 'broxbourne'],
#                                             ['Arrive', '09:45']]},
#             'emotion': [{'annotation': 0, 'annotator': '6e869d8c'},
#                         {'annotation': 0, 'annotator': '6965ef79'},
#                         {'annotation': 0, 'annotator': '8bc9c701'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Train-Inform', 'Dest', 'broxbourne', 7, 7],
#                           ['Train-Inform', 'Arrive', '09:45', 9, 9]],
#             'text': 'I want a train that arrives in broxbourne by 09:45.'},
#            {'dialog_act': {'Train-OfferBook': [['Day', 'friday'],
#                                                ['Leave', '05:01']]},
#             'emotion': [],
#             'span_info': [['Train-OfferBook', 'Day', 'friday', 7, 7],
#                           ['Train-OfferBook', 'Leave', '05:01', 9, 9]],
#             'text': 'I can book you a train for friday at 05:01, is that '
#                     'alright?'},
#            {'dialog_act': {'Train-Inform': [['Day', 'monday'],
#                                             ['Depart', 'cambridge']]},
#             'emotion': [{'annotation': 0, 'annotator': '6e869d8c'},
#                         {'annotation': 2, 'annotator': '6965ef79'},
#                         {'annotation': 2, 'annotator': '8bc9c701'},
#                         {'emotion': 2, 'sentiment': 1}],
#             'span_info': [['Train-Inform', 'Day', 'monday', 11, 11],
#                           ['Train-Inform', 'Depart', 'cambridge', 7, 7]],
#             'text': 'No. I need to depart from Cambridge and leave on Monday. '
#                     'Can you find me a more suitable train?'},
#            {'dialog_act': {},
#             'emotion': [],
#             'span_info': [],
#             'text': 'I have four trains leaving cambridge on monday and going '
#                     'to broxbourne.  Arriving every hour from 06:01-09:01.  '
#                     'What time would you prefer?'},
#            {'dialog_act': {},
#             'emotion': [{'annotation': 0, 'annotator': '6e869d8c'},
#                         {'annotation': 6, 'annotator': '6965ef79'},
#                         {'annotation': 2, 'annotator': '8bc9c701'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [],
#             'text': 'I would prefer to arrive at 9:01.'},
#            {'dialog_act': {'Train-Inform': [['Id', 'TR5517'],
#                                             ['Dest', 'broxbourne'],
#                                             ['Arrive', '09:01'],
#                                             ['Day', 'Monday']],
#                            'Train-OfferBook': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Train-Inform', 'Id', 'TR5517', 0, 0],
#                           ['Train-Inform', 'Dest', 'broxbourne', 4, 4],
#                           ['Train-Inform', 'Arrive', '09:01', 6, 6],
#                           ['Train-Inform', 'Day', 'Monday', 7, 7]],
#             'text': 'TR5517 will arrive in broxbourne by 09:01 Monday. Would '
#                     'you like to book a seat for that one?'},
#            {'dialog_act': {'Train-Inform': [['People', '5']],
#                            'Train-Request': [['Ref', '?']]},
#             'emotion': [{'annotation': 6, 'annotator': '6e869d8c'},
#                         {'annotation': 0, 'annotator': '6965ef79'},
#                         {'annotation': 0, 'annotator': '8bc9c701'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Train-Inform', 'People', '5', 4, 4]],
#             'text': 'Yes please, for 5 people. Can I get the reference '
#                     'number?'},
#            {'dialog_act': {'Train-OfferBooked': [['Arrive', '9:01'],
#                                                  ['Day', 'Monday'],
#                                                  ['Ref', '1YXEN4V3'],
#                                                  ['Id', 'TR5517'],
#                                                  ['Dest', 'broxbourne']],
#                            'general-reqmore': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Train-OfferBooked', 'Arrive', '9:01', 8, 8],
#                           ['Train-OfferBooked', 'Day', 'Monday', 10, 10],
#                           ['Train-OfferBooked', 'Ref', '1YXEN4V3', 18, 18],
#                           ['Train-OfferBooked', 'Id', 'TR5517', 3, 3],
#                           ['Train-OfferBooked', 'Dest', 'broxbourne', 6, 6]],
#             'text': 'I have booked TR5517 arriving in broxbourne at 9:01 on '
#                     'Monday for you. The reference number is 1YXEN4V3. Will '
#                     'that be all?'},
#            {'dialog_act': {'Attraction-Inform': [['Area', 'centre'],
#                                                  ['Type', 'park']]},
#             'emotion': [{'annotation': 0, 'annotator': '6e869d8c'},
#                         {'annotation': 0, 'annotator': '6965ef79'},
#                         {'annotation': 0, 'annotator': '8bc9c701'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Attraction-Inform', 'Area', 'centre', 9, 9],
#                           ['Attraction-Inform', 'Type', 'park', 6, 6]],
#             'text': "I'm also looking for a park in the centre."},
#            {'dialog_act': {'Attraction-Inform': [['Fee', '4 pounds'],
#                                                  ['Type', 'park'],
#                                                  ['Area', 'centre'],
#                                                  ['Name',
#                                                   'cambridge university '
#                                                   'botanic gardens']]},
#             'emotion': [],
#             'span_info': [['Attraction-Inform', 'Fee', '4 pounds', 20, 21],
#                           ['Attraction-Inform', 'Type', 'park', 5, 5],
#                           ['Attraction-Inform', 'Area', 'centre', 8, 8],
#                           ['Attraction-Inform',
#                            'Name',
#                            'cambridge university botanic gardens',
#                            11,
#                            14]],
#             'text': 'The only results for a park in the centre area is '
#                     'cambridge university botanic gardens. The entrance fee is '
#                     '4 pounds. Would you like the address?'},
#            {'dialog_act': {'Attraction-Request': [['Addr', '?'],
#                                                   ['Post', '?']]},
#             'emotion': [{'annotation': 6, 'annotator': '6e869d8c'},
#                         {'annotation': 0, 'annotator': '6965ef79'},
#                         {'annotation': 3, 'annotator': '8bc9c701'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [],
#             'text': 'Yes please give me the address in the postcode'},
#            {'dialog_act': {'Attraction-Inform': [['Addr', 'Bateman Street'],
#                                                  ['Post', 'cb21jf']],
#                            'general-reqmore': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Attraction-Inform', 'Addr', 'Bateman Street', 3, 4],
#                           ['Attraction-Inform', 'Post', 'cb21jf', 9, 9]],
#             'text': 'The address is Bateman Street and the postcode is cb21jf. '
#                     'Do you need anything else?'},
#            {'dialog_act': {'general-thank': [['none', 'none']]},
#             'emotion': [{'annotation': 6, 'annotator': '6e869d8c'},
#                         {'annotation': 6, 'annotator': '6965ef79'},
#                         {'annotation': 6, 'annotator': '8bc9c701'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [],
#             'text': "That's all I need. Thank you!"},
#            {'dialog_act': {'general-bye': [['none', 'none']],
#                            'general-welcome': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'Your welcome! Goodbye.'}]}),
#  ('SNG02176.json',
#   {'log': [{'dialog_act': {'Hospital-Inform': [['Department', 'cardiology']]},
#             'emotion': [{'annotation': 1, 'annotator': '2466b16a'},
#                         {'annotation': 0, 'annotator': 'f92a5e1b'},
#                         {'annotation': 0, 'annotator': '64cfa354'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hospital-Inform',
#                            'Department',
#                            'cardiology',
#                            8,
#                            8]],
#             'text': 'Is there a local hospital that has a cardiology '
#                     'department?'},
#            {'dialog_act': {'Hospital-Inform': [['Addr', 'Hills Rd , Cambridge'],
#                                                ['Department', 'cardiology']]},
#             'emotion': [],
#             'span_info': [['Hospital-Inform',
#                            'Addr',
#                            'Hills Rd , Cambridge',
#                            4,
#                            7],
#                           ['Hospital-Inform',
#                            'Department',
#                            'cardiology',
#                            9,
#                            9]],
#             'text': 'Addenbrookes Hospital located at Hills Rd, Cambridge has '
#                     'cardiology.  Do you need their phone number?'},
#            {'dialog_act': {'Hospital-Request': [['Addr', '?'], ['Post', '?']]},
#             'emotion': [{'annotation': 0, 'annotator': '2466b16a'},
#                         {'annotation': 0, 'annotator': 'f92a5e1b'},
#                         {'annotation': 0, 'annotator': '64cfa354'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [],
#             'text': 'I just need their address and postcode please'},
#            {'dialog_act': {'Hospital-Inform': [['Addr', 'Hills Rd , Cambridge'],
#                                                ['Post', 'CB20QQ']]},
#             'emotion': [],
#             'span_info': [['Hospital-Inform',
#                            'Addr',
#                            'Hills Rd , Cambridge',
#                            3,
#                            6],
#                           ['Hospital-Inform', 'Post', 'CB20QQ', 9, 9]],
#             'text': 'Their address is Hills Rd, Cambridge, postcode \tCB20QQ'},
#            {'dialog_act': {'general-thank': [['none', 'none']]},
#             'emotion': [{'annotation': 6, 'annotator': '2466b16a'},
#                         {'annotation': 6, 'annotator': 'f92a5e1b'},
#                         {'annotation': 6, 'annotator': '64cfa354'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [],
#             'text': 'Thank you and goodbye.'},
#            {'dialog_act': {'general-bye': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [],
#             'text': "You're welcome. I am glad I could assist you at TownInfo "
#                     'centre. Goodbye.'}]}),
#  ('PMUL4865.json',
#   {'log': [{'dialog_act': {'Hotel-Inform': [['Type', 'guesthouse'],
#                                             ['Internet', 'yes']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bf71ed'},
#                         {'annotation': 0, 'annotator': 'e9852fb2'},
#                         {'annotation': 5, 'annotator': '7db9fb1b'},
#                         {'emotion': 5, 'sentiment': 2}],
#             'span_info': [['Hotel-Inform', 'Type', 'guesthouse', 14, 14]],
#             'text': "Good day. I'm headed into town and I need help finding a "
#                     'guesthouse that offers free wifi please'},
#            {'dialog_act': {'Hotel-Request': [['Area', '?'], ['Price', '?']],
#                            'general-greet': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'Okay, I can help with that. What is your price range and '
#                     'what area would you like to stay in?'},
#            {'dialog_act': {'Hotel-Inform': [['Price', 'moderate']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bf71ed'},
#                         {'annotation': 0, 'annotator': 'e9852fb2'},
#                         {'annotation': 0, 'annotator': '7db9fb1b'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Price', 'moderate', 15, 15]],
#             'text': "The area doesn't matter, but I would like it to be in the "
#                     'moderate price range.'},
#            {'dialog_act': {'Hotel-Inform': [['Choice', 'four'],
#                                             ['Choice', 'one'],
#                                             ['Area', 'north'],
#                                             ['Area', 'east']],
#                            'Hotel-Recommend': [['Name', 'Acorn']]},
#             'emotion': [],
#             'span_info': [['Hotel-Recommend', 'Name', 'Acorn', 15, 15],
#                           ['Hotel-Inform', 'Choice', 'four', 0, 0],
#                           ['Hotel-Inform', 'Choice', 'one', 7, 7],
#                           ['Hotel-Inform', 'Area', 'north', 5, 5],
#                           ['Hotel-Inform', 'Area', 'east', 10, 10]],
#             'text': 'Four great options in the north and one in the east, I '
#                     'suggest the Acorn.'},
#            {'dialog_act': {'Hotel-Inform': [['Stay', '2'],
#                                             ['Day', 'monday'],
#                                             ['People', '6']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bf71ed'},
#                         {'annotation': 0, 'annotator': 'e9852fb2'},
#                         {'annotation': 5, 'annotator': '7db9fb1b'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [['Hotel-Inform', 'Stay', '2', 14, 14],
#                           ['Hotel-Inform', 'Day', 'monday', 18, 18],
#                           ['Hotel-Inform', 'People', '6', 11, 11]],
#             'text': "Okay, i'll try it out!  Book me for 6 people, 2 nights "
#                     'starting this monday.'},
#            {'dialog_act': {'Booking-Book': [['Ref', 'M2YEYUTC']],
#                            'general-reqmore': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Booking-Book', 'Ref', 'M2YEYUTC', 9, 9]],
#             'text': 'Your booking was successful! Your reference number is '
#                     'M2YEYUTC. Is there anything else I can help with?'},
#            {'dialog_act': {'Restaurant-Inform': [['Food', 'italian'],
#                                                  ['Price', 'moderate']]},
#             'emotion': [{'annotation': 6, 'annotator': '68bf71ed'},
#                         {'annotation': 6, 'annotator': 'e9852fb2'},
#                         {'annotation': 6, 'annotator': '7db9fb1b'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [['Restaurant-Inform', 'Food', 'italian', 13, 13],
#                           ['Restaurant-Inform', 'Price', 'moderate', 11, 11]],
#             'text': 'Thank you.  Yes, I also need to find a moderately priced '
#                     'Italian restaurant.'},
#            {'dialog_act': {'Restaurant-Inform': [['Choice', '5']],
#                            'Restaurant-Request': [['Area', '?']]},
#             'emotion': [],
#             'span_info': [['Restaurant-Inform', 'Choice', '5', 2, 2]],
#             'text': 'there are 5. which side of town do you prefer?'},
#            {'dialog_act': {'Restaurant-Inform': [['Area', 'centre']]},
#             'emotion': [{'annotation': 0, 'annotator': '68bf71ed'},
#                         {'annotation': 0, 'annotator': 'e9852fb2'},
#                         {'annotation': 0, 'annotator': '7db9fb1b'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Restaurant-Inform', 'Area', 'centre', 5, 5]],
#             'text': "I would refer in the center and  as long as it's moderate "
#                     'pricing.'},
#            {'dialog_act': {'Restaurant-Inform': [['Addr',
#                                                   'Regent Street City Centre'],
#                                                  ['Addr',
#                                                   'Jesus Lane Fen Ditton'],
#                                                  ['Area', 'centre'],
#                                                  ['Choice', 'two'],
#                                                  ['Choice', 'One'],
#                                                  ['Choice', 'the other'],
#                                                  ['Name', 'pizza express']],
#                            'Restaurant-Select': [['none', 'none']],
#                            'general-reqmore': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Restaurant-Inform',
#                            'Addr',
#                            'Regent Street City Centre',
#                            12,
#                            15],
#                           ['Restaurant-Inform',
#                            'Addr',
#                            'Jesus Lane Fen Ditton',
#                            20,
#                            23],
#                           ['Restaurant-Inform', 'Area', 'centre', 8, 8],
#                           ['Restaurant-Inform', 'Choice', 'two', 2, 2],
#                           ['Restaurant-Inform', 'Choice', 'One', 10, 10],
#                           ['Restaurant-Inform', 'Choice', 'the other', 17, 18],
#                           ['Restaurant-Inform', 'Name', 'pizza express', 3, 4]],
#             'text': 'There are two pizza express locations in the centre. One '
#                     'in Regent Street City Centre and the other in Jesus Lane '
#                     'Fen Ditton. Would one of those work for you?'},
#            {'dialog_act': {'Restaurant-Inform': [['Time', '19:15'],
#                                                  ['Day', 'monday'],
#                                                  ['People', '6']]},
#             'emotion': [{'annotation': 6, 'annotator': '68bf71ed'},
#                         {'annotation': 0, 'annotator': 'e9852fb2'},
#                         {'annotation': 6, 'annotator': '7db9fb1b'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [['Restaurant-Inform', 'Time', '19:15', 21, 21],
#                           ['Restaurant-Inform', 'Day', 'monday', 18, 18],
#                           ['Restaurant-Inform', 'People', '6', 27, 27]],
#             'text': "Yes, let's go for the one in Regent Street City Centre. "
#                     'It will be on Monday, at 19:15, and there will be 6 '
#                     'people. '},
#            {'dialog_act': {'Booking-Book': [['Ref', 'G6O0PMU6'],
#                                             ['Name', 'Pizza Express']]},
#             'emotion': [],
#             'span_info': [['Booking-Book', 'Ref', 'G6O0PMU6', 12, 12],
#                           ['Booking-Book', 'Name', 'Pizza Express', 5, 6]],
#             'text': 'You are booked for the Pizza Express. Your reference '
#                     'number is G6O0PMU6.'},
#            {'dialog_act': {'general-thank': [['none', 'none']]},
#             'emotion': [{'annotation': 6, 'annotator': '68bf71ed'},
#                         {'annotation': 6, 'annotator': 'e9852fb2'},
#                         {'annotation': 6, 'annotator': '7db9fb1b'},
#                         {'emotion': 6, 'sentiment': 2}],
#             'span_info': [],
#             'text': 'thank you that will be all'},
#            {'dialog_act': {'general-bye': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'Have a good visit!'}]}),
#  ('MUL0196.json',
#   {'log': [{'dialog_act': {'Hotel-Inform': [['Type', 'hotel'],
#                                             ['Parking', 'yes']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Type', 'hotel', 5, 5]],
#             'text': 'I was looking for a hotel in the center of town that '
#                     'offers free parking.'},
#            {'dialog_act': {'Hotel-Inform': [['Name', 'the Gonville Hotel'],
#                                             ['Name', 'University Arms Hotel']]},
#             'emotion': [],
#             'span_info': [['Hotel-Inform', 'Name', 'the Gonville Hotel', 2, 4],
#                           ['Hotel-Inform',
#                            'Name',
#                            'University Arms Hotel',
#                            6,
#                            8]],
#             'text': 'I found the Gonville Hotel and University Arms Hotel that '
#                     'meets your criteria.'},
#            {'dialog_act': {'Hotel-Inform': [['Type', 'guesthouse'],
#                                             ['Price', 'expensive']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Type', 'guesthouse', 9, 9],
#                           ['Hotel-Inform', 'Price', 'expensive', 3, 3]],
#             'text': 'Is the hotel expensive, and is it a guesthouse?'},
#            {'dialog_act': {'Hotel-Inform': [['Price', 'expensive'],
#                                             ['Type', 'guesthouses'],
#                                             ['Name', 'The Gonville Hotel'],
#                                             ['Name', 'University Arms Hotel']],
#                            'Hotel-NoOffer': [['Type', 'guesthouse']]},
#             'emotion': [],
#             'span_info': [['Hotel-NoOffer', 'Type', 'guesthouse', 15, 15],
#                           ['Hotel-Inform', 'Price', 'expensive', 8, 8],
#                           ['Hotel-Inform', 'Type', 'guesthouses', 18, 18],
#                           ['Hotel-Inform', 'Name', 'The Gonville Hotel', 0, 2],
#                           ['Hotel-Inform',
#                            'Name',
#                            'University Arms Hotel',
#                            4,
#                            6]],
#             'text': 'The Gonville Hotel and University Arms Hotel is '
#                     'expensive, but it is not a guesthouse. The guesthouses '
#                     'that meet your criteria are cheap.'},
#            {'dialog_act': {'Hotel-Inform': [['Type', 'hotel'],
#                                             ['Price', 'expensive']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Type', 'hotel', 5, 5],
#                           ['Hotel-Inform', 'Price', 'expensive', 8, 8]],
#             'text': 'Okay, how about any hotels that are expensive that has '
#                     'free parking.'},
#            {'dialog_act': {'Hotel-NoOffer': [['Type', 'hotels']]},
#             'emotion': [],
#             'span_info': [['Hotel-NoOffer', 'Type', 'hotels', 3, 3]],
#             'text': 'There are no hotels that match that requirement.'},
#            {'dialog_act': {'Hotel-Inform': [['Type', 'hotel']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Type', 'hotel', 3, 3]],
#             'text': 'How about a hotel type instead of guesthouse?'},
#            {'dialog_act': {'Booking-Inform': [['none', 'none']],
#                            'Hotel-Inform': [['Type', 'hotel'],
#                                             ['Choice', '2'],
#                                             ['Name', 'gonville hotel'],
#                                             ['Name', 'university arms hotel'],
#                                             ['Price', 'expensive'],
#                                             ['Area', 'town centre']]},
#             'emotion': [],
#             'span_info': [['Hotel-Inform', 'Type', 'hotel', 6, 6],
#                           ['Hotel-Inform', 'Choice', '2', 2, 2],
#                           ['Hotel-Inform', 'Name', 'gonville hotel', 14, 15],
#                           ['Hotel-Inform',
#                            'Name',
#                            'university arms hotel',
#                            19,
#                            21],
#                           ['Hotel-Inform', 'Price', 'expensive', 5, 5],
#                           ['Hotel-Inform', 'Area', 'town centre', 8, 9]],
#             'text': 'There are 2 results for expensive hotels in town centre. '
#                     'One is the gonville hotel, the other university arms '
#                     'hotel. Would you like to book one of these?'},
#            {'dialog_act': {'Hotel-Inform': [['Type', 'hotel'],
#                                             ['Stay', '4'],
#                                             ['Day', 'tuesday'],
#                                             ['People', '2'],
#                                             ['Name', 'Gonville Hotel']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 6, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Type', 'hotel', 4, 4],
#                           ['Hotel-Inform', 'Stay', '4', 9, 9],
#                           ['Hotel-Inform', 'Day', 'tuesday', 12, 12],
#                           ['Hotel-Inform', 'People', '2', 6, 6],
#                           ['Hotel-Inform', 'Name', 'Gonville Hotel', 3, 4]],
#             'text': 'Yes please book Gonville Hotel for 2 people for 4 nights '
#                     'starting tuesday'},
#            {'dialog_act': {'Booking-NoBook': [['none', 'none']],
#                            'Booking-Request': [['Day', '?'], ['Stay', '?']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'I am sorry. That hotel is unavailable for your requested '
#                     'stay. Would you like to pick a different day or shorter '
#                     'stay?'},
#            {'dialog_act': {'Hotel-Inform': [['Stay', '3']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Stay', '3', 3, 3]],
#             'text': 'Can you try 3 nights instead?'},
#            {'dialog_act': {'Booking-Book': [['Ref', '4QYJH7Y5'],
#                                             ['Stay', '3'],
#                                             ['Name', 'Gonville hotel']],
#                            'general-reqmore': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Booking-Book', 'Ref', '4QYJH7Y5', 14, 14],
#                           ['Booking-Book', 'Stay', '3', 7, 7],
#                           ['Booking-Book', 'Name', 'Gonville hotel', 4, 5]],
#             'text': 'I have booked the Gonville hotel for 3 nights. The '
#                     'reference number is 4QYJH7Y5. Can I help you with '
#                     'anything else?'},
#            {'dialog_act': {'Hotel-Inform': [['Price', 'expensive']],
#                            'Restaurant-Inform': [['Food', 'modern american'],
#                                                  ['Price', 'expensive']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Hotel-Inform', 'Price', 'expensive', 15, 15],
#                           ['Restaurant-Inform', 'Price', 'expensive', 15, 15],
#                           ['Restaurant-Inform',
#                            'Food',
#                            'modern american',
#                            5,
#                            6]],
#             'text': 'Yes, are there any modern american restaurants in the '
#                     'center of town? Something expensive.'},
#            {'dialog_act': {'Restaurant-NoOffer': [['none', 'none']],
#                            'Restaurant-Request': [['Price', '?']],
#                            'Restaurant-Select': [['Price', 'less expensive']]},
#             'emotion': [],
#             'span_info': [['Restaurant-Select',
#                            'Price',
#                            'less expensive',
#                            14,
#                            15]],
#             'text': "Sorry, but there aren't any restaurants that meet those "
#                     'criteria. Something less expensive, perhaps?'},
#            {'dialog_act': {'Restaurant-Inform': [['Food', 'modern european']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Restaurant-Inform',
#                            'Food',
#                            'modern european',
#                            3,
#                            4]],
#             'text': 'How about a modern european restaurant?'},
#            {'dialog_act': {'Booking-Inform': [['none', 'none']],
#                            'Restaurant-Recommend': [['Name',
#                                                      'darrys cookhouse and '
#                                                      'wine shop']]},
#             'emotion': [],
#             'span_info': [['Restaurant-Recommend',
#                            'Name',
#                            'darrys cookhouse and wine shop',
#                            5,
#                            9]],
#             'text': 'Yes, I can recommend darrys cookhouse and wine shop. '
#                     'Would you like me to make a reservation?'},
#            {'dialog_act': {},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [],
#             'text': 'Yes I want a reservation for 2 people at 14:30'},
#            {'dialog_act': {'Booking-Request': [['Day', '?']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'Which day would you like the reservation for?'},
#            {'dialog_act': {'Restaurant-Inform': [['Day', 'tuesday']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 0, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [['Restaurant-Inform', 'Day', 'tuesday', 0, 0]],
#             'text': 'Tuesday please. Also I need the booking reference number '
#                     'when you are done please.'},
#            {'dialog_act': {'Booking-Book': [['Ref', 'Z7E6UORT']],
#                            'general-reqmore': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [['Booking-Book', 'Ref', 'Z7E6UORT', 7, 7]],
#             'text': 'Booking confirmed! The reference number is Z7E6UORT. Can '
#                     'I help you with anything else today? '},
#            {'dialog_act': {'general-thank': [['none', 'none']]},
#             'emotion': [{'annotation': 0, 'annotator': '427469a1'},
#                         {'annotation': 6, 'annotator': 'e0665d5e'},
#                         {'annotation': 0, 'annotator': 'f7bfc66d'},
#                         {'emotion': 0, 'sentiment': 0}],
#             'span_info': [],
#             'text': "No that's all. Thank you. "},
#            {'dialog_act': {'general-bye': [['none', 'none']],
#                            'general-welcome': [['none', 'none']]},
#             'emotion': [],
#             'span_info': [],
#             'text': 'Thank you very much for using the Cambridge Towninfo '
#                     'Centre. Have a wonderful day!'}]})]

# %%
#the dataset contains many json files, each representing one conversation between a call agent and a caller. Within each conversation are the different speaker turns, each containing the following elements:
#dialog_act: the dialogue act of the speaker turn, containing a description of the domain of the conversation and intention of the speaker (ex. Restaurant-Inform), not relevant for the analysis
#**emotion**: the emotion of the speaker turn (Ex. 0) - 0: neutral, 1: fearful, sad, disappointed, 2: dissatisfied, disliking, 3: apologetic, 4: abusive, 5: excited, happy, anticipating, 6: satisfied, liking
#**sentiment**: the sentiment of the speaker turn - 0: neutral, 1: negative, 2: positive
#span_info: more info about the speaker turn
#**text**: the transcribed text of the speaker
#The elements enclosed in double asterisks ** are the ones that will be used for the sentiment analysis

# %% [markdown]
# # Step 3: Make a list of all the dialogues from the EmoWoz database with associated sentiment and emotion labels

# %%
from pprint import pprint

#Extracting all the lines of dialogues spoken by the user together with their sentiment label and emotion label
sentiment_list = []
for item in emowoz_database:
    for second_level in emowoz_database[item]:
        #There are only sentiment labels for user sentences in EmoWoz; there are no sentiment labels for agent dialogue. Only 
        #take every second dialogue from EmoWoz because all dialogues alternate between user and agent and user always starts
        #dialogue. Picked sufficiently large index number of each dialogue with 100 so that all dialogues are definitely included.
        for third_level in emowoz_database[item][second_level][::2]:
            sentiment_list.append({"text": third_level["text"], "sentiment": third_level["emotion"][3]["sentiment"], "emotion": third_level["emotion"][3]["emotion"]})
# Print the first 10 items in sentiment_list in a more readable format
pprint(sentiment_list[:10], width=80)
# Out:
# [{'emotion': 0,
#   'sentiment': 0,
#   'text': 'How are you doing? Are there any European restaurants in the city '
#           'center?'},
#  {'emotion': 0,
#   'sentiment': 0,
#   'text': 'Can I get the name and address of one of the most inexpensive '
#           'ones?'},
#  {'emotion': 6,
#   'sentiment': 2,
#   'text': 'Thanks so much. I am also looking for places to go in town. Can you '
#           'help me with that?'},
#  {'emotion': 0,
#   'sentiment': 0,
#   'text': 'I would like to see colleges.  Can you please recommend one with no '
#           'entrance fee, and let me know the area.  Thank you.'},
#  {'emotion': 6, 'sentiment': 2, 'text': 'Thank you.  That was all I needed.'},
#  {'emotion': 0,
#   'sentiment': 0,
#   'text': 'I want a train that arrives in broxbourne by 09:45.'},
#  {'emotion': 2,
#   'sentiment': 1,
#   'text': 'No. I need to depart from Cambridge and leave on Monday. Can you '
#           'find me a more suitable train?'},
#  {'emotion': 0, 'sentiment': 0, 'text': 'I would prefer to arrive at 9:01.'},
#  {'emotion': 0,
#   'sentiment': 0,
#   'text': 'Yes please, for 5 people. Can I get the reference number?'},
#  {'emotion': 0,
#   'sentiment': 0,
#   'text': "I'm also looking for a park in the centre."}]

# %% [markdown]
# # Step 4: Making a dataframe with the text, sentiment and emotion from EmoWoz and removing all unneceessary information

# %%
result_df = pd.DataFrame(sentiment_list, columns=['text','sentiment','emotion'])
result_df
# Out:
#                                                     text  sentiment  emotion
# 0      How are you doing? Are there any European rest...          0        0
# 1      Can I get the name and address of one of the m...          0        0
# 2      Thanks so much. I am also looking for places t...          2        6
# 3      I would like to see colleges.  Can you please ...          0        0
# 4                     Thank you.  That was all I needed.          2        6
# ...                                                  ...        ...      ...
# 71519  I want to start my stay on Sunday for 7 people...          0        0
# 71520  Can you recommend a tour of the college near t...          2        5
# 71521  Why don't you search for a boat attraction ins...          0        0
# 71522    Could you give me the address and entrance fee?          0        0
# 71523       That is it. Thank you so much for your help.          2        6
#
# [71524 rows x 3 columns]

# %%
#Removing all rows that contain neutral sentiment, as sentiment analysis models used cannot recognize neutral sentiment
no_neutral_sentiment_df = result_df.query("sentiment != 0")
no_neutral_sentiment_df
# Out:
#                                                     text  sentiment  emotion
# 2      Thanks so much. I am also looking for places t...          2        6
# 4                     Thank you.  That was all I needed.          2        6
# 6      No. I need to depart from Cambridge and leave ...          1        2
# 11                         That's all I need. Thank you!          2        6
# 14                                Thank you and goodbye.          2        6
# ...                                                  ...        ...      ...
# 71511                                Thank you goodbye.           2        6
# 71515  No, that is all.  You have been very helpful. ...          2        6
# 71516  We are visiting cambridge for the first time a...          2        5
# 71520  Can you recommend a tour of the college near t...          2        5
# 71523       That is it. Thank you so much for your help.          2        6
#
# [20219 rows x 3 columns]

# %%
#Adding two conditional columns that put into words what the sentiment and emotion score mean. The mapping is based on the
#README.md file from https://zenodo.org/record/6506504#.ZFF4gc7P3b1
no_neutral_sentiment_df = no_neutral_sentiment_df.copy()
no_neutral_sentiment_df["sentiment_name"] = no_neutral_sentiment_df['sentiment'].apply(lambda x: 'Positive' if x == 2 else 'Negative')
no_neutral_sentiment_df["emotion_name"] = no_neutral_sentiment_df['emotion'].apply(lambda x: 'Neutral' if x == 0 else 'Fearful, sad, disappointed' if x == 1 else 'Dissatisfied, disliking' if x == 2 else 'Apologetic' if x == 3 else 'Abusive' if x == 4 else 'Excited, happy, anticipating' if x == 5 else 'Satisfied, liking')
no_neutral_sentiment_df.head(10)
# Out:
#                                                  text  sentiment  emotion  \
# 2   Thanks so much. I am also looking for places t...          2        6
# 4                  Thank you.  That was all I needed.          2        6
# 6   No. I need to depart from Cambridge and leave ...          1        2
# 11                      That's all I need. Thank you!          2        6
# 14                             Thank you and goodbye.          2        6
# 15  Good day. I'm headed into town and I need help...          2        5
# 17  Okay, i'll try it out!  Book me for 6 people, ...          2        6
# 18  Thank you.  Yes, I also need to find a moderat...          2        6
# 20  Yes, let's go for the one in Regent Street Cit...          2        6
# 21                         thank you that will be all          2        6
#
#    sentiment_name                  emotion_name
# 2        Positive             Satisfied, liking
# 4        Positive             Satisfied, liking
# 6        Negative       Dissatisfied, disliking
# 11       Positive             Satisfied, liking
# 14       Positive             Satisfied, liking
# 15       Positive  Excited, happy, anticipating
# 17       Positive             Satisfied, liking
# 18       Positive             Satisfied, liking
# 20       Positive             Satisfied, liking
# 21       Positive             Satisfied, liking

# %%
#In the text column, replace all semicolons within with commas or apostrophes so that later the separator ; functions as intended later
no_neutral_sentiment_df['text'] = no_neutral_sentiment_df['text'].str.replace(';', ',', regex=False)

# %%
#Remove any newline characters from the text column
no_neutral_sentiment_df['text'] = no_neutral_sentiment_df['text'].str.replace('\n', ' ', regex=False)

# %% [markdown]
# # Step 5: Export dataframe to an Excel file

# %%
# Put the dataframe into an Excel file and save it
no_neutral_sentiment_df.to_excel("EmoWoz_Dataset.xlsx", index=False, engine="openpyxl")
